# %% [markdown]
# # `Telco Customer Churn Dataset`
#
# ## `Context`
# Predict behavior to retain customers. You can analyze all relevant customer data and develop focused customer retention programs.
# [IBM Sample Data Sets]
#
# ## `Content`
# Each row represents a customer, each column contains customer’s attributes described on the column Metadata.
#
# The data set includes information about:
#
# - **Customers who left within the last month** – the column is called *Churn*
#
# - **Services that each customer has signed up for** – phone, multiple lines, internet, online security, online backup, device protection, tech support, and streaming TV and movies
#
# - **Customer account information** – how long they’ve been a customer, contract, payment method, paperless billing, monthly charges, and total charges
#
# - **Demographic info about customers** – gender, age range, and if they have partners and dependents
#
#
# ## `Column Descriptions`
#
# - **customerID**: Unique identifier assigned to each customer.
#
# - **gender**: Indicates the customer's gender (Male or Female).
#
# - **SeniorCitizen**: Indicates whether the customer is a senior citizen (1 = Yes, 0 = No).
#
# - **Partner**: Indicates whether the customer has a partner (Yes or No).
#
# - **Dependents**: Indicates whether the customer has dependents (Yes or No).
#
# - **tenure**: Number of months the customer has been with the company.
#
# - **PhoneService**: Indicates whether the customer has a phone service (Yes or No).
#
# - **MultipleLines**: Indicates whether the customer has multiple phone lines (Yes, No, or No phone service).
#
# - **InternetService**: Type of internet service used by the customer (DSL, Fiber optic, or No).
#
# - **OnlineSecurity**: Indicates whether the customer has online security (Yes, No, or No internet service).
#
# - **OnlineBackup**: Indicates whether the customer has online backup (Yes, No, or No internet service).
#
# - **DeviceProtection**: Indicates whether the customer has device protection (Yes, No, or No internet service).
#
# - **TechSupport**: Indicates whether the customer has technical support (Yes, No, or No internet service).
#
# - **StreamingTV**: Indicates whether the customer uses streaming TV services (Yes, No, or No internet service).
#
# - **StreamingMovies**: Indicates whether the customer uses streaming movie services (Yes, No, or No internet service).
#
# - **Contract**: Specifies the type of contract (Month-to-month, One year, or Two year).
#
# - **PaperlessBilling**: Indicates whether the customer uses paperless billing (Yes or No).
#
# - **PaymentMethod**: Specifies the payment method (Electronic check, Mailed check, Bank transfer, or Credit card).
#
# - **MonthlyCharges**: The amount charged to the customer on a monthly basis.
#
# - **TotalCharges**: The total amount charged to the customer over the entire period.
#
# - **Churn**: Indicates whether the customer has left the company (Yes or No).

# %% [markdown]
# ## `Objectives`
# * > 1- Data Understanding
# * > 2- Univariate Analysis
# * > 3- BiVariate Analysis

# %% [markdown]
# ## Import Helper Library

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
pd.set_option('display.max_columns',None)

# %% [markdown]
# ## `Data Understanding`

# %% [markdown]
# ### Read DataSet

# %%
df = pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %% [markdown]
# ### Data OverView

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 7038          Yes               Yes             DSL            Yes
# 7039          Yes               Yes     Fiber optic             No
# 7040           No  No phone service             DSL            Yes
# 7041          Yes               Yes     Fiber optic             No
# 7042          Yes                No     Fiber optic            Yes
#
#      OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies  \
# 7038           No              Yes         Yes         Yes             Yes
# ...

# %% [markdown]
# ### Data Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# * Data with 7043 entries, 0 to 7042
# * Data with 21 columns Feature
# * Data with float64(1), int64(2), object(18) columns

# %% [markdown]
# ### data Preprocessing

# %%
# We changed the type of the TotalCharges variable.

df["TotalCharges"] = pd.to_numeric(df["TotalCharges"], errors='coerce')

# %% [markdown]
# ### Check Missing  & Duplicated Records

# %%
df.isnull().mean()*100
# Out:
# customerID          0.000000
# gender              0.000000
# SeniorCitizen       0.000000
# Partner             0.000000
# Dependents          0.000000
# tenure              0.000000
# PhoneService        0.000000
# MultipleLines       0.000000
# InternetService     0.000000
# OnlineSecurity      0.000000
# OnlineBackup        0.000000
# DeviceProtection    0.000000
# TechSupport         0.000000
# StreamingTV         0.000000
# StreamingMovies     0.000000
# Contract            0.000000
# PaperlessBilling    0.000000
# PaymentMethod       0.000000
# MonthlyCharges      0.000000
# TotalCharges        0.156183
# Churn               0.000000
# dtype: float64

# %%
df.drop(['customerID'] , axis = 1 , inplace = True )

# %%
df.duplicated().sum()
# Out:
# np.int64(22)

# %%
# drop duplicated data
df.drop_duplicates(inplace=True , ignore_index=True)

# %% [markdown]
# ## `Univariate Analysis (EDA)`

# %% [markdown]
# #### gender feature

# %%
df['gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
colors = ['red', 'yellow']
explode = (0.05, 0.05)
df['gender'].value_counts().plot(kind = 'pie' , y='gender' , autopct='%1.0f%%' , colors=colors, explode=explode)
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# * The data is split fifty-fifty between males and females

# %% [markdown]
# #### SeniorCitizen feature

# %%
df['SeniorCitizen'].unique()
# Out:
# array([0, 1])

# %%
df['SeniorCitizen'] = df['SeniorCitizen'].map({0: 'NO', 1: 'Yes'})

# %%
df['SeniorCitizen'].value_counts().plot(kind = 'pie' , y='SeniorCitizen' , autopct='%1.0f%%' , colors=colors, explode=explode)
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# * The majority are of young age

# %% [markdown]
# #### Partner Feature

# %%
df['Partner'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['Partner'].value_counts().plot(kind = 'pie' , y='Partner' , autopct='%1.0f%%' , colors=colors, explode=explode)
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# * The majority are married

# %% [markdown]
# #### Dependents Feature

# %%
df['Dependents'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['Dependents'].value_counts().plot(kind = 'pie' , y='Dependents' , autopct='%1.0f%%' , colors=colors, explode=explode)
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# * The majority of customers have no dependents

# %% [markdown]
# #### tenure Feature

# %%
df['tenure'].describe().to_frame()
# Out:
#             tenure
# count  7021.000000
# mean     32.469449
# std      24.534965
# min       0.000000
# 25%       9.000000
# 50%      29.000000
# 75%      55.000000
# max      72.000000

# %%
sns.boxplot(df['tenure'])
# Out:
# <Axes: ylabel='tenure'>

# %%
sns.displot(x = df['tenure'])

# %%
df[df['tenure'] < 1]
# Out:
#       gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 488   Female            NO     Yes        Yes       0           No
# 753     Male            NO      No        Yes       0          Yes
# 936   Female            NO     Yes        Yes       0          Yes
# 1081    Male            NO     Yes        Yes       0          Yes
# 1338  Female            NO     Yes        Yes       0           No
# 3323    Male            NO     Yes        Yes       0          Yes
# 3817    Male            NO     Yes        Yes       0          Yes
# 4370  Female            NO     Yes        Yes       0          Yes
# 5207    Male            NO     Yes        Yes       0          Yes
# 6652  Female            NO     Yes        Yes       0          Yes
# 6735    Male            NO      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# ...

# %% [markdown]
# * tenure with no outliers points and no missing values or wrong values
# * `tenure = 0` does not indicate an error, but likely means the customer subscribed within the current month and hasn't completed a full month yet

# %% [markdown]
# #### PhoneService Feature

# %%
df['PhoneService'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['PhoneService'].value_counts()
# Out:
# PhoneService
# Yes    6339
# No      682
# Name: count, dtype: int64

# %%
df['PhoneService'].value_counts().plot(kind = 'pie' , y='PhoneService' , autopct='%1.0f%%' , colors=colors, explode=explode)
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# * The majority of customers have no Phone Service

# %% [markdown]
# #### MultipleLines Feature

# %%
df['MultipleLines'].unique()
# Out:
# array(['No phone service', 'No', 'Yes'], dtype=object)

# %%
df['MultipleLines'].value_counts()
# Out:
# MultipleLines
# No                  3368
# Yes                 2971
# No phone service     682
# Name: count, dtype: int64

# %%
sns.countplot(df['MultipleLines'])
# Out:
# <Axes: xlabel='count', ylabel='MultipleLines'>

# %% [markdown]
# * The majority of customers have no Phone Service

# %% [markdown]
# #### InternetService Feature

# %%
df['InternetService'].unique()
# Out:
# array(['DSL', 'Fiber optic', 'No'], dtype=object)

# %%
df['InternetService'].value_counts(normalize=True)
# Out:
# InternetService
# Fiber optic    0.440108
# DSL            0.344538
# No             0.215354
# Name: proportion, dtype: float64

# %%
px.histogram(df[df['InternetService']=='No'],y='InternetService',color='Churn',barmode='group')

# %%
sns.countplot(df['InternetService'])
# Out:
# <Axes: xlabel='count', ylabel='InternetService'>

# %% [markdown]
# * Approximately 44% of customers use Fiber optic internet service

# %% [markdown]
# #### OnlineSecurity Feature

# %%
df['OnlineSecurity'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
df['OnlineSecurity'].value_counts(normalize=True)
# Out:
# OnlineSecurity
# No                     0.497080
# Yes                    0.287566
# No internet service    0.215354
# Name: proportion, dtype: float64

# %%
sns.countplot(df['OnlineSecurity'])
# Out:
# <Axes: xlabel='count', ylabel='OnlineSecurity'>

# %% [markdown]
# * Approximately 50% of customers have no Online Security"

# %% [markdown]
# #### OnlineBackup Feature

# %%
df['OnlineBackup'].unique()
# Out:
# array(['Yes', 'No', 'No internet service'], dtype=object)

# %%
df['OnlineBackup'].value_counts(normalize=True)
# Out:
# OnlineBackup
# No                     0.438684
# Yes                    0.345962
# No internet service    0.215354
# Name: proportion, dtype: float64

# %%
sns.countplot(df['OnlineBackup'])
# Out:
# <Axes: xlabel='count', ylabel='OnlineBackup'>

# %% [markdown]
# * Approximately 43% of customers have no Online Backup"

# %% [markdown]
# #### DeviceProtection Feature

# %%
df['DeviceProtection'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
df['DeviceProtection'].value_counts(normalize=True)
# Out:
# DeviceProtection
# No                     0.439681
# Yes                    0.344965
# No internet service    0.215354
# Name: proportion, dtype: float64

# %%
sns.countplot(df['DeviceProtection'])
# Out:
# <Axes: xlabel='count', ylabel='DeviceProtection'>

# %% [markdown]
# * DeviceProtection and OnlineBackup follow similar patterns, as the majority of customers who don't have Online Backup also don't have Device Protection

# %% [markdown]
# #### TechSupport Feature

# %%
df['TechSupport'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
df['TechSupport'].value_counts(normalize=True)
# Out:
# TechSupport
# No                     0.493519
# Yes                    0.291127
# No internet service    0.215354
# Name: proportion, dtype: float64

# %%
sns.countplot(df['TechSupport'])
# Out:
# <Axes: xlabel='count', ylabel='TechSupport'>

# %% [markdown]
# * The majority of customers have no TechSupport

# %% [markdown]
# #### StreamingTV Feature

# %%
df['StreamingTV'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
df['StreamingTV'].value_counts(normalize=True)
# Out:
# StreamingTV
# No                     0.399088
# Yes                    0.385558
# No internet service    0.215354
# Name: proportion, dtype: float64

# %%
sns.countplot(df['StreamingTV'])
# Out:
# <Axes: xlabel='count', ylabel='StreamingTV'>

# %% [markdown]
# * The majority of customers have no TechSupport

# %% [markdown]
# #### StreamingMovies Feature

# %%
df['StreamingMovies'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
df['StreamingMovies'].value_counts(normalize=True)
# Out:
# StreamingMovies
# No                     0.395528
# Yes                    0.389118
# No internet service    0.215354
# Name: proportion, dtype: float64

# %%
sns.countplot(df['StreamingMovies'])
# Out:
# <Axes: xlabel='count', ylabel='StreamingMovies'>

# %% [markdown]
# * Streaming Movies and StreamingTV follow similar patterns, as the majority of customers who don't have StreamingTV also don't have Streaming Movies

# %% [markdown]
# #### Contract Feature

# %%
df['Contract'].unique()
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %%
df['Contract'].value_counts(normalize=True)
# Out:
# Contract
# Month-to-month    0.548782
# Two year          0.241419
# One year          0.209799
# Name: proportion, dtype: float64

# %%
sns.countplot(df['Contract'])
# Out:
# <Axes: xlabel='count', ylabel='Contract'>

# %% [markdown]
# * The majority of customers are on a Month-to-Month contract

# %% [markdown]
# #### PaperlessBilling Feature

# %%
df['PaperlessBilling'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['PaperlessBilling'].value_counts().plot(kind = 'pie' , y='PaperlessBilling' , autopct='%1.0f%%' , colors=colors, explode=explode)
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# * The majority of customers use Paperless Billing

# %% [markdown]
# #### PaymentMethod Feature

# %%
df['PaymentMethod'].unique()
# Out:
# array(['Electronic check', 'Mailed check', 'Bank transfer (automatic)',
#        'Credit card (automatic)'], dtype=object)

# %%
df['PaymentMethod'].value_counts(normalize=True)
# Out:
# PaymentMethod
# Electronic check             0.335992
# Mailed check                 0.227318
# Bank transfer (automatic)    0.219912
# Credit card (automatic)      0.216778
# Name: proportion, dtype: float64

# %%
sns.countplot(df['PaymentMethod'])
# Out:
# <Axes: xlabel='count', ylabel='PaymentMethod'>

# %% [markdown]
# * The majority of customers are Electronic check

# %% [markdown]
# #### MonthlyCharges Feature

# %%
df['MonthlyCharges'].describe().to_frame()
# Out:
#        MonthlyCharges
# count     7021.000000
# mean        64.851894
# std         30.069001
# min         18.250000
# 25%         35.750000
# 50%         70.400000
# 75%         89.900000
# max        118.750000

# %%
sns.boxplot(df['MonthlyCharges'])
# Out:
# <Axes: ylabel='MonthlyCharges'>

# %%
sns.histplot(x = df['MonthlyCharges'])
# Out:
# <Axes: xlabel='MonthlyCharges', ylabel='Count'>

# %%
df['InternetService'].value_counts()
# Out:
# InternetService
# Fiber optic    3090
# DSL            2419
# No             1512
# Name: count, dtype: int64

# %%
df[df['MonthlyCharges'] <= 27]['InternetService'].value_counts()
# Out:
# InternetService
# No     1512
# DSL      80
# Name: count, dtype: int64

# %% [markdown]
# * The first peak (≤ $27) is because all 1,512 customers with no Internet Service are clustered between $18 and $27
# * Monthly Charges with no outliers points and no missing values or wrong values

# %% [markdown]
# #### Total Charges Feature

# %%
df[df['TotalCharges'].isna()]
# Out:
#       gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 488   Female            NO     Yes        Yes       0           No
# 753     Male            NO      No        Yes       0          Yes
# 936   Female            NO     Yes        Yes       0          Yes
# 1081    Male            NO     Yes        Yes       0          Yes
# 1338  Female            NO     Yes        Yes       0           No
# 3323    Male            NO     Yes        Yes       0          Yes
# 3817    Male            NO     Yes        Yes       0          Yes
# 4370  Female            NO     Yes        Yes       0          Yes
# 5207    Male            NO     Yes        Yes       0          Yes
# 6652  Female            NO     Yes        Yes       0          Yes
# 6735    Male            NO      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# ...

# %%
df.dropna(subset=['TotalCharges'], inplace=True)

# %% [markdown]
# * Dropping rows where TotalCharges is NaN since they all have tenure = 0,
# * meaning they haven't completed a full month yet and have no actual charges

# %%
df['TotalCharges'].describe().to_frame()
# Out:
#        TotalCharges
# count   7010.000000
# mean    2290.353388
# std     2266.820832
# min       18.800000
# 25%      408.312500
# 50%     1403.875000
# 75%     3807.837500
# max     8684.800000

# %%
sns.boxplot(df['TotalCharges'])
# Out:
# <Axes: ylabel='TotalCharges'>

# %%
sns.histplot(x = df['TotalCharges'])
# Out:
# <Axes: xlabel='TotalCharges', ylabel='Count'>

# %%
px.scatter(df,x='tenure',y='TotalCharges')

# %% [markdown]
# * Total Charges with no outliers points and no missing values or wrong values

# %% [markdown]
# #### Churn Feature

# %%
df['Churn'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['Churn'].value_counts().plot(kind = 'pie' , y='Churn' , autopct='%1.0f%%' , colors=colors, explode=explode)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[184], line 1
# ----> 1 df['Churn'].value_counts().plot(kind = 'pie' , y='Churn' , autopct='%1.0f%%' , colors=colors, explode=explode)
#
# File c:\myanacondaa\envs\lord\Lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\myanacondaa\envs\lord\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# ...

# %%
df['Churn'].value_counts().to_frame()
# Out:
#        count
# Churn
# No      5153
# Yes     1857

# %% [markdown]
# * ooopppsss !!! imbalanced label :(

# %% [markdown]
# ## `Now Time For Bivariate Analysis`
# *  First we will see effect of all features with Target (Churn)
# *  second see all Features with each other and show correlations and so on ..

# %%
sns.countplot(df,x='gender',hue='Churn')
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
sns.countplot(df,x='SeniorCitizen',hue='Churn')
# Out:
# <Axes: xlabel='SeniorCitizen', ylabel='count'>

# %%
sns.countplot(df,x='Partner',hue='Churn')
# Out:
# <Axes: xlabel='Partner', ylabel='count'>

# %%
sns.countplot(df,x='Dependents',hue='Churn')
# Out:
# <Axes: xlabel='Dependents', ylabel='count'>

# %%
sns.displot(df,x='tenure',hue='Churn')

# %% [markdown]
# * Customers with low tenure (0-5 months) show the highest churn rate,
# * Customers (60-70 months) are the least likely to churn.

# %%
sns.countplot(df,x='PhoneService',hue='Churn')
# Out:
# <Axes: xlabel='PhoneService', ylabel='count'>

# %%
sns.countplot(df,x='MultipleLines',hue='Churn')
# Out:
# <Axes: xlabel='MultipleLines', ylabel='count'>

# %%
sns.countplot(df,x='InternetService',hue='Churn')
# Out:
# <Axes: xlabel='InternetService', ylabel='count'>

# %%
sns.countplot(df,x='OnlineSecurity',hue='Churn')
# Out:
# <Axes: xlabel='OnlineSecurity', ylabel='count'>

# %% [markdown]
# * Customers without online security show the highest churn rate

# %%
sns.countplot(df,x='OnlineBackup',hue='Churn')
# Out:
# <Axes: xlabel='OnlineBackup', ylabel='count'>

# %% [markdown]
# * Customers without Online Backup show the highest churn rate

# %%
sns.countplot(df,x='DeviceProtection',hue='Churn')
# Out:
# <Axes: xlabel='DeviceProtection', ylabel='count'>

# %% [markdown]
# * Customers without Device Protection show the highest churn rate

# %%
sns.countplot(df,x='TechSupport',hue='Churn')
# Out:
# <Axes: xlabel='TechSupport', ylabel='count'>

# %% [markdown]
# * Customers without Tech Support show the highest churn rate

# %%
sns.countplot(df,x='StreamingTV',hue='Churn')
# Out:
# <Axes: xlabel='StreamingTV', ylabel='count'>

# %%
sns.countplot(df,x='StreamingMovies',hue='Churn')
# Out:
# <Axes: xlabel='StreamingMovies', ylabel='count'>

# %%
sns.countplot(df,x='StreamingMovies',hue='Churn')
# Out:
# <Axes: xlabel='StreamingMovies', ylabel='count'>

# %%
sns.countplot(df,x='Contract',hue='Churn')
# Out:
# <Axes: xlabel='Contract', ylabel='count'>

# %% [markdown]
# * Customers with month-to-month contracts show the highest churn rate

# %%
sns.countplot(df,x='PaperlessBilling',hue='Churn')
# Out:
# <Axes: xlabel='PaperlessBilling', ylabel='count'>

# %% [markdown]
# *  Customers who use paperless billing show the highest churn rate

# %%
plt.figure(figsize=(10, 5))
sns.countplot(df,x='PaymentMethod',hue='Churn')
# Out:
# <Axes: xlabel='PaymentMethod', ylabel='count'>

# %% [markdown]
# *  Customers who use Electronic check show the highest churn rate

# %%
sns.displot(df,x='MonthlyCharges',hue='Churn')

# %% [markdown]
# * Customers with higher monthly charges (70-100$) tend to churn more,
#  while customers with low monthly charges (~20$) are the most loyal
# and least likely to leave the service

# %%
sns.displot(df,x='TotalCharges',hue='Churn')

# %% [markdown]
# * Customers with low total charges (0-2000$) have the highest churn rate

# %%
px.histogram(df, x='Contract', color='PaymentMethod', barmode='group',
                    title='Contract vs Payment Method')

# %%
px.histogram(df, x='Contract', color='InternetService', barmode='group',
                    title='Contract vs Internet Service')

# %%
px.scatter(df, x='tenure', y='TotalCharges', color='Churn',
                  title='Tenure vs Total Charges')

# %%
px.histogram(df, x='InternetService', color='OnlineSecurity', barmode='group',
                    title='Internet Service vs Online Security')

# %%
px.pie(df,names='InternetService')

# %%
px.histogram(df, x='InternetService', color='TechSupport', barmode='group',
                    title='Internet Service vs Tech Support')

# %%
px.histogram(df, x='InternetService', color='StreamingTV', barmode='group',
                    title='Internet Service vs Streaming TV')

# %%
px.box(df, x='SeniorCitizen', y='MonthlyCharges', color='Churn',
              title='Senior Citizen vs Monthly Charges')

# %% [markdown]
# * Most of the outlier points in this segment appear to have only **PhoneService**, which explains their relatively low **MonthlyCharges**.

# %%
# df[
#     (df['SeniorCitizen'] == 1) &
#     (df['Churn'] == 'Yes') &
#     (df['MonthlyCharges'] <= 40.65)
# ]

# %%
px.box(df, x='Contract', y='MonthlyCharges', color='Churn',
               title='Contract vs Monthly Charges')

# %%
px.histogram(df, x='Partner', color='Dependents', barmode='group',
                     title='Partner vs Dependents')

# %%
px.imshow(df[['tenure', 'MonthlyCharges', 'TotalCharges']].corr(),
                text_auto=True,
                title='Correlation Heatmap - Numerical Features',
            )

# %% [markdown]
# # `--------------------------Conclusion------------------------------`

# %% [markdown]
# * > Convert dtype of TotalCharges from string to float
# * > Dropping rows where TotalCharges is NaN since they all have tenure = 0 , meaning they haven't completed a full month yet and have no actual charges
# * > Dropping 24 duplicate rows to ensure data quality and avoid biased results

# %%
df['TotalCharges'].dtype
# Out:
# dtype('float64')

# %%
df['TotalCharges'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ##### Finally we will save Modified data frame into csv file

# %%
df.to_csv('Telco_Customer_Churn_Modified.csv' , index=False)
